# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A04C7/Pardhu/blob/master/Gradient__Decent_%26_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np


def gradient_decent(x,y):
  m_curr = 1
  b_curr = 0
  n = len(x)
  iterations = 1000
  learning_rate = 0.01

  for i in range(iterations):
    y_pred = m_curr * x + b_curr
    cost = sum([val **2 for val in (y-y_pred)])
    md = -2*np.sum(x*(y-y_pred))
    bd = -2*np.sum(y-y_pred)
    m_curr = m_curr-learning_rate * md
    b_curr = b_curr-learning_rate * bd
    print("m =  {}, c =  {} ,iteration =  {}, cost {}".format(m_curr,b_curr,i, cost))
   
x = np.array([0.5,2.3,2.9])
y = np.array([1.4,1.9,3.2])
gradient_decent(x,y)
# Out:
# m =  1.008, c =  0.016000000000000007 ,iteration =  0, cost 1.0599999999999998
# m =  1.011944, c =  0.030128000000000005 ,iteration =  1, cost 1.03112
# m =  1.013177032, c =  0.042958704000000014 ,iteration =  2, cost 1.0110554607839997
# m =  1.012603347816, c =  0.05487900011200002 ,iteration =  3, cost 0.9951361731291349
# m =  1.010830807762568, c =  0.06614947845425603 ,iteration =  4, cost 0.9812468286142118
# m =  1.0082679718530265, c =  0.07694579766206792 ,iteration =  5, cost 0.9684274290436092
# m =  1.0051893867725563, c =  0.08738650101109884 ,iteration =  6, cost 0.9562404435015484
# m =  1.0017794867477479, c =  0.09755172085836149 ,iteration =  7, cost 0.9444846592632793
# m =  0.998162113767273, c =  0.10749575611761654 ,iteration =  8, cost 0.9330657943874046
# m =  0.9944203678287956, c =  0.11725552978109043 ,iteration =  9, cost 0.9219379919570668
# m =  0.9906099548095174, c =  0.12685627606174232 ,iteration =  10, cost 0.9110773643186286
# ...

# %%
import numpy as np


def gradient_decent1(x,y):
  m_curr = 0
  b_curr = 0
  n = len(x)
  iterations = 200
  learning_rate = 0.05

  for i in range(iterations):
    y_pred = m_curr * x + b_curr
    cost = (1/n) * sum([val **2 for val in (y-y_pred)])
    md = -(2/n) * np.sum(x*(y-y_pred))
    bd = -(2/n) * np.sum(y-y_pred)
    m_curr = m_curr-learning_rate * md
    b_curr = b_curr-learning_rate * bd
    print("m =  {}, c =  {} ,iteration =  {}, cost {}".format(m_curr,b_curr,i, cost))
   
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])
gradient_decent1(x,y)
# Out:
# m =  3.1, c =  0.9 ,iteration =  0, cost 89.0
# m =  2.52, c =  0.78 ,iteration =  1, cost 3.8599999999999994
# m =  2.6140000000000003, c =  0.8460000000000001 ,iteration =  2, cost 0.9763999999999999
# m =  2.5848, c =  0.8772 ,iteration =  3, cost 0.8513360000000004
# m =  2.57836, c =  0.91404 ,iteration =  4, cost 0.81970064
# m =  2.567952, c =  0.949128 ,iteration =  5, cost 0.7921173536
# m =  2.5584664, c =  0.9838296 ,iteration =  6, cost 0.7655590528640001
# m =  2.54900448, c =  1.01790672 ,iteration =  7, cost 0.7398944506073604
# m =  2.539727536, c =  1.0514147040000001 ,iteration =  8, cost 0.7150903372945663
# m =  2.5306028352, c =  1.0843549728000001 ,iteration =  9, cost 0.6911177570948888
# m =  2.52163322464, c =  1.1167386249600002 ,iteration =  10, cost 0.667948830166544
# m =  2.512815090048, c =  1.1485747950720002 ,iteration =  11, cost 0.6455566148366696
# m =  2.5041460524735997, c =  1.1798727885504001 ,iteration =  12, cost 0.6239150727392739
# ...

# %%
                                          #***_Seaborn_***
import matplotlib.pyplot as plt 
import seaborn as sns 
  
# use to set style of background of plot 
sns.set(style ="whitegrid") 
  
# loading data-set 
iris = sns.load_dataset('iris'); 
  
ax = sns.stripplot(x = 'species', y = 'sepal_length', data = iris); 
  
plt.title('Graph') 
  
plt.show()

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
  
# use to set style of background of plot 
sns.set(style ="whitegrid") 
  
# loading data-set 
iris = sns.load_dataset('iris'); 
  
ax = sns.swarmplot(x = 'species', y = 'sepal_length', data = iris); 
  
plt.title('Graph') 
   
plt.show()

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
  
# use to set style of background of plot 
sns.set(style ="whitegrid") 
  
# loading data-set 
iris = sns.load_dataset('iris'); 
  
ax = sns.swarmplot(x = 'sepal_length', y = 'species', data = iris);   
  
plt.title('Graph') 
   
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.distplot(df['petal_length'],kde = False)
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.stripplot(x = "species", y = "petal_length", data = df)
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.stripplot(x = "species", y = "petal_length", data = df, jitter = True)
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.stripplot(x = "species", y = "petal_length", data = df)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Initialize Figure and Axes object
fig, ax = plt.subplots()

tips = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

ax.violinplot(tips["total_bill"], vert=False)

plt.show()

# %%
#Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset("tips")

sns.violinplot(x = "total_bill", data=tips)

plt.show()

# %%
#Import necessarily libraries
import matplotlib.pyplot as plt
import seaborn as sns

titanic = sns.load_dataset("titanic")

g = sns.factorplot("class", "survived", "sex", data=titanic, kind="bar", palette="muted", legend=False)
                   
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# Import the libraries
import matplotlib.pyplot as plt
import seaborn as sns 

tips = sns.load_dataset("tips")

ax = sns.boxplot(x="total_bill", data=tips)


ax.set_title("boxplot")


plt.show()
